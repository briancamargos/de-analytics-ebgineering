# %% [markdown]
# # Aula 02

# %% [markdown]
# ## Modelagem de tabelas especializadas com dados agrupados e/ou sumarizados.

# %% [markdown]
# ## Técnicas de limpeza de dados para geração de tabelas harmonizadas e especializadas.

# %%
#Bibliotecas

import pandas as pd

# %%
gatos = pd.read_csv('cat_breeds.csv')

# %%
gatos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 62 non-null     object
#  1   length               62 non-null     object
#  2   origin               62 non-null     object
#  3   min_life_expectancy  62 non-null     float64
#  4   max_life_expectancy  62 non-null     float64
#  5   min_weight           62 non-null     float64
#  6   max_weight           62 non-null     float64
#  7   family_friendly      62 non-null     int64
#  8   shedding             62 non-null     int64
#  9   general_health       62 non-null     int64
#  10  playfulness          62 non-null     int64
#  11  children_friendly    62 non-null     int64
#  12  grooming             62 non-null     int64
#  13  intelligence         62 non-null     int64
#  14  other_pets_friendly  62 non-null     int64
# ...

# %%
colunas = {'name':'Nome', 'origin':'Origem','min_life_expectancy':'Expectativa minima de vida','man_life_expectancy':'Expectativa maxima de vida','min_weight':'peso mínimo','max_weight':'peso maximo','family_friendly':'Dócil','shedding':'solta pelos','general_health':'Saúde em geral','playfulness':'Gosta de brincar','children_friendly':'Gosta de crianças','grooming':'Limpo','intelligence':'inteligencia','other_pets_friendly':'Tranquilo para outros pets'}
gatos.rename(columns=colunas, inplace=True)
gatos
# Out:
#                   Nome           length                    Origem  \
# 0           Abyssinian  12 to 16 inches            Southeast Asia
# 1               Aegean           Medium                    Greece
# 2     American Bobtail           Medium  United States and Canada
# 3   American Shorthair  12 to 15 inches             United States
# 4    American Wirehair  Medium to large             United States
# ..                 ...              ...                       ...
# 57              Toyger           Medium             United States
# 58      Turkish Angora           Medium            Ankara, Turkey
# 59         Turkish Van  14 to 17 inches          Lake Van, Turkey
# 60    Ukrainian Levkoy           Medium                    Russia
# 61      York Chocolate            Large             United States
#
#     Expectativa minima de vida  max_life_expectancy  peso mínimo  peso maximo  \
# 0                          9.0                 15.0          6.0         10.0
# ...

# %%
gatos.isna().sum()
# Out:
# Nome                          0
# length                        0
# Origem                        0
# Expectativa minima de vida    0
# max_life_expectancy           0
# peso mínimo                   0
# peso maximo                   0
# Dócil                         0
# solta pelos                   0
# Saúde em geral                0
# Gosta de brincar              0
# Gosta de crianças             0
# Limpo                         0
# inteligencia                  0
# Tranquilo para outros pets    0
# dtype: int64
